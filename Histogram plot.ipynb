# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(20,100,50)
x
# Out:
# array([88, 70, 70, 63, 96, 85, 31, 78, 93, 55, 56, 71, 99, 92, 39, 79, 57,
#        81, 62, 71, 80, 69, 76, 54, 75, 82, 68, 53, 68, 70, 41, 35, 59, 79,
#        43, 77, 63, 33, 49, 58, 71, 45, 25, 56, 67, 54, 29, 43, 63, 34],
#       dtype=int32)

# %%
data=x
data
# Out:
# array([88, 70, 70, 63, 96, 85, 31, 78, 93, 55, 56, 71, 99, 92, 39, 79, 57,
#        81, 62, 71, 80, 69, 76, 54, 75, 82, 68, 53, 68, 70, 41, 35, 59, 79,
#        43, 77, 63, 33, 49, 58, 71, 45, 25, 56, 67, 54, 29, 43, 63, 34],
#       dtype=int32)

# %%
plt.hist(data,color='r',edgecolor='b',linewidth=3)
plt.xlabel("python",fontsize=15)
plt.ylabel("popularity")
plt.title("data interpretation")
plt.show()
